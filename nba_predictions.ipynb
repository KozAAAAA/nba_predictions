# %%
from nba_api.stats.endpoints import leagueleaders
import pandas as pd

# %%
player_stats_df = leagueleaders.LeagueLeaders().get_data_frames()[0]
player_stats_df
# Out:
#      PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0      1629029     1              Luka Doncic  1610612742  DAL  70  2624  804
# 1      1628983     2  Shai Gilgeous-Alexander  1610612760  OKC  75  2553  796
# 2       203507     3    Giannis Antetokounmpo  1610612749  MIL  73  2567  837
# 3      1628973     4            Jalen Brunson  1610612752  NYK  77  2726  790
# 4       203999     5             Nikola Jokic  1610612743  DEN  79  2737  822
# ..         ...   ...                      ...         ...  ...  ..   ...  ...
# 567    1628382   563           Justin Jackson  1610612750  MIN   2     1    0
# 568    1629232   563             Kaiser Gates  1610612740  NOP   1     7    0
# 569    1630608   563          Malcolm Cazalon  1610612765  DET   1     3    0
# 570    1631199   563           Ron Harper Jr.  1610612761  TOR   1     4    0
# 571    1627853   563         Ryan Arcidiacono  1610612752  NYK  20    45    0
#
# ...

# %%
all_nba_df = pd.read_html("https://en.wikipedia.org/wiki/All-NBA_Team")[7:9]
all_nba_df = pd.concat(all_nba_df)

all_rookie_df = pd.read_html("https://en.wikipedia.org/wiki/NBA_All-Rookie_Team")[5]
all_rookie_df = all_rookie_df.drop(range(0, 132))

awards = [all_nba_df, all_rookie_df]


def postprocess_award(award):

    award = award.droplevel(0, axis=1)
    award = award.drop(columns=["Teams", "Positions"], errors="ignore")
    award = award.set_index("Season")
    indexes = sorted(set(award.index.to_list()), reverse=True)

    postprocessed_award = pd.DataFrame()
    for index in indexes:
        season = award.loc[index]
        season = pd.concat(values for _, values in season.items())
        season = season.reset_index(drop=True)
        season = season.str.replace(r"[\*\^\[\(\†].*", "", regex=True)
        postprocessed_award.insert(0, index, season)

    return postprocessed_award


all_nba_df = postprocess_award(all_nba_df)
all_rookie_df = postprocess_award(all_rookie_df)

display(all_nba_df)
display(all_rookie_df)
# Out:
#               1988–89          1989–90            1990–91          1991–92  \
# 0         Karl Malone      Karl Malone        Karl Malone      Karl Malone
# 1     Charles Barkley  Charles Barkley    Charles Barkley     Chris Mullin
# 2      Akeem Olajuwon    Patrick Ewing     David Robinson   David Robinson
# 3      Michael Jordan    Magic Johnson     Michael Jordan   Michael Jordan
# 4       Magic Johnson   Michael Jordan      Magic Johnson    Clyde Drexler
# 5        Tom Chambers       Larry Bird  Dominique Wilkins   Scottie Pippen
# 6        Chris Mullin    Tom Chambers        Chris Mullin  Charles Barkley
# 7       Patrick Ewing   Akeem Olajuwon      Patrick Ewing    Patrick Ewing
# 8       John Stockton    John Stockton     Kevin Johnson      Tim Hardaway
# 9       Kevin Johnson   Kevin Johnson       Clyde Drexler    John Stockton
# 10  Dominique Wilkins     James Worthy       James Worthy    Dennis Rodman
# ...

# %%
# Filter out below 1979
#

# %%
# 2023-2024 season
# Filter out Games Played (GP) lower than 65
# Filter out Minutes Played (MIN) lower than 20
